# %% [markdown]
# # Brownian motion
#
# Een van de bekendste voorbeelden van botsende deeltjes in de natuur is Brownian motion.
# Fijn gemalen pollen in water lijken te dansen in willekeurige richting.
# Dit komt doordat de pollen worden geraakt door watermoleculen die in alle richtingen bewegen.
# Omdat de pollen veel zwaarder zijn dan watermoleculen, dus de beweging van de pollen is veel langzamer en minder "intens" dan die van de watermoleculen.
# Dit proces van willekeurige beweging door botsingen met kleinere deeltjes wordt Brownian motion genoemd en kunnen we simuleren op basis van ons (premature) botsingsmodel.
# Daarbij kunnen we ook gebruik maken van de zojuist geleerde manier van tracking van deeltjes, waarbij we een zowel het zware bolletjes als een enkel deeltje kunnen volgen.
#
# Let op!
# We bestuderen hier nog geen thermische effecten, deze opdrachten zijn met name bedoeld om beter te begrijpen hoe het botsingsmodel in elkaar zit.
#
# ```{warning}
# In dit notebook zitten delen waar ruimte is om code toe te voegen, maar waarbij je denkt... waarom dan?
# In een latere opdracht moet je terug naar die cell en de juiste code toevoegen.
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Maken van de ParticleClass

class ParticleClass:
    # Het maken van het deeltje
    def __init__(self, m, v, r, R, c):
        self.m = m                         
        self.v = np.array(v, dtype=float)  
        self.r = np.array(r, dtype=float)  
        self.R = np.array(R, dtype=float)  
        self.c = c

    # Het updaten van de positie, eventueel met zwaartekracht
    def update_position(self):
        self.r += self.v * dt #+ 1/2 * a * dt**2  
              
    # Harde wand
    def boxcollision(self):
        if abs(self.r[0]) + self.R > Box_length: 
            self.v[0] = -self.v[0]                                  # Omdraaien van de snelheid
            self.r[0] = np.sign(self.r[0]) * (Box_length - self.R)  # Zet terug net binnen box                 
        if abs(self.r[1]) + self.R > Box_length: 
            self.v[1] = -self.v[1]     
            self.r[1] = np.sign(self.r[1]) * (Box_length - self.R) 
            
    @property
    def momentum(self):
        return self.m * self.v
    
    @property
    def kin_energy(self):
        return 1/2 * self.m * np.dot(self.v, self.v)

# %%
# Aanmaken van de randvoorwaarden en initiele condities
Box_size_0 = 10
Box_length_0 = Box_size_0/2
Box_length = Box_length_0     # De grootte van de box kan wijzigen!

# Particles
dt = 0.1
particles = []
N = 40
v_0 = 1

dt = 0.04

# Aanmaken van deeltjes
for i in range(N-1):
    vx = np.random.uniform(-v_0,v_0)
    vy = np.random.choice([-1, 1])*np.sqrt(v_0**2-vx**2)        
    pos = Box_length_0*np.random.uniform(-1,1,2)
    particles.append(ParticleClass(m=1.0, v=[vx, vy], r = pos, R=.5,c='blue')) 

particles.append(ParticleClass(m=20.0, v=[0, 0], r = [0, 0], R=.5,c='red'))

# %% [markdown]
# ```{exercise} Brownian motion
# :label: ex-brownian-1
#
# Leg uit wat er in de laatste regel van bovenstaande script gebeurt.
# Voeg voor deze regel goede metadata toe.
# ```
#
# ```{solution} ex-brownian-1
#
# #your code/answer:
#
# Het laatste deeltje heeft een veel grotere massa en straal dan de andere deeltjes die worden aangemaakt. Daarnaast staat die ook stil in het midden van de doos, dit gesimuleerde deeltje fungeert als zware massa (watermolecuul) waar lichte deeltjes (pollen) tegenaan botsen.
#
#
# ```

# %% [markdown]
# Er is een doos vol met deeltjes op willekeurige positie aangemaakt.
# We willen kijken waar de deeltjes zijn terechtgekomen.
# Hieronder staat dit weergegeven.

# %%
# Inspecteren van beginsituatie
plt.figure()

plt.xlabel('x')
plt.ylabel('y')

plt.xlim(-Box_length_0,Box_length_0)
plt.ylim(-Box_length_0,Box_length_0)


for particle, particle_object in enumerate(particles):
    plt.plot(particle_object.r[0],particle_object.r[1],color=particle_object.c,marker='.')
    plt.arrow(particle_object.r[0],particle_object.r[1],
                particle_object.v[0],particle_object.v[1], 
                head_width=0.05, head_length=0.1, color='red')
plt.show()

# %% [markdown]
# ```{exercise}
# :label: ex-brownian-2
#
# Er staat ook code met comments ervoor, wat doet deze code?
# Check je antwoord door de comments weg te halen.
# Hoe wordt er voor gezorgd dat de snelheid van elk deeltje gelijk is?
# ```
#
# ```{solution} ex-brownian-2
#
# #your code/answer:
#
# Alle deeltjes hebben dezelfde snelheidsgrootte, maar ieder een verschillende richting. De functie plt.arrow tekent een pijl vanaf de positie van het deeltje die de snelheid weergeeft. Waar grootte gelijk is bij ieder deeltje en de richting verschilt.
#
# ```
#
# We gaan nu de functies van de simulatie weer aanroepen:

# %%
# Het bepalen of er een botsing plaats vindt

def collide_detection(self, other):
    dx = self.r[0] - other.r[0]
    dy = self.r[1] - other.r[1]
    rr = self.R + other.R
    return  dx**2+dy**2 < rr**2 
        
def particle_collision(p1: ParticleClass, p2: ParticleClass):
    """ past snelheden aan uitgaande van overlap """
    m1, m2 = p1.m, p2.m
    delta_r = p1.r - p2.r
    delta_v = p1.v - p2.v
    dot_product = np.dot(delta_r, delta_v)
    
    # Als deeltjes van elkaar weg bewegen dan geen botsing
    if dot_product >= 0: # '='-teken voorkomt ook problemen als delta_r == \vec{0}
        return
    
    distance_squared = np.dot(delta_r, delta_r) 
    # Botsing oplossen volgens elastische botsing in 2D
    p1.v -= 2 * m2 / (m1 + m2) * dot_product / distance_squared * delta_r
    p2.v += 2 * m1 / (m1 + m2) * dot_product / distance_squared * delta_r

collisions_count = 0
collisions_over_time = []

def handle_collisions(particles):
    """ alle onderlinge botsingen afhandelen voor deeltjes in lijst """
    num_particles = len(particles)
    global collisions_over_time
    global collisions_count
    collisions_stap = 0
    for i in range(num_particles):
        for j in range(i+1, num_particles):
            if collide_detection(particles[i], particles[j]):
                particle_collision(particles[i], particles[j])
                collisions_stap += 1
    collisions_count += collisions_stap
    collisions_over_time.append(collisions_count)
    return collisions_stap

# %% [markdown]
# In onderstaande code geven we de code voor de simulatie en volgen we de positie van het zware deeltje.

# %%
# tracken van het zware deeltje
track_x = []
track_y = []

#tracks losse kleinere deeltjes
track1_x = []
track1_y = []
track1_x1 = []
track1_y1 = []

for i in range(400):
    for p in particles:
        p.update_position()    # Update positie        
        p.boxcollision()         # Wandbotsing werkt per deeltje
        
    handle_collisions(particles)

#your code/answer
    track1_x.append(particles[N-2].r[0])
    track1_y.append(particles[N-2].r[1])
    track1_x1.append(particles[N-3].r[0])
    track1_y1.append(particles[N-3].r[1])
    track_x.append(particles[N-1].r[0])
    track_y.append(particles[N-1].r[1])
    
#your code/answer

plt.figure()
plt.plot(track_x,track_y,'r')
plt.plot(track1_x,track1_y,"b")
plt.plot(track1_x1,track1_y1,"g")
plt.show()

# %% [markdown]
# ```{exercise} Brownian motion in beeld
# :label: ex-brownian-3
# - Draai de onderstaande simulatie een keer en bestudeer de output.
# - Voeg zelf een tweede tracking toe van een licht deeltje en verbeter de plot.
#
# - Wat zijn overeenkomsten en verschillen tussen de beweging van de twee deeltjes?
#
# Het zware deeltje (rood) beweegt langzaam in vergelijking met de lichtere deeltjes (groen en blauw). De snelheidsveranderingen van de lichtere deeltjes zijn veel extremer dan die van het zware deeltje.
#
# - Wat valt je op als je de simulatie een aantal keer runt?
#
# De paden van alle drie de deeltjes verschillen per run. De beginposities en snelheidsrichtingen worden dan ook steeds willekeurig gekozen. De kans op excact hetzelfde pad is dus vrijwel onmogelijk. Maar verder valt wel op dat gemiddeld gezien alle deeltjes hetzelfde karakter in hun beweging behouden. De lichte deeltjes bewegen sneller, over langere rechte stukken en veranderen abrupt van richting. Terwijl het zware deeltje zich op redelijk dezelfde manier rondom zijn startpostitie verplaatst.
#
# ```

# %% [markdown]
# We zouden gevoel willen krijgen voor het aantal botsingen dat per tijdseenheid plaatsvindt.
# Elke keer dat er een botsing plaatsvindt, zou de counter met 1 omhoog moeten gaan.
# Idealiter wordt het aantal botsingen opgeslagen in een array zodat je het aantal botsingen als functie van de tijd kunt weergeven.
#
# ```{exercise}
# Pas bovenstaand idee toe in de eerder gemaakte code.
# Plot hieronder het aantal botsingen als functie van de tijd.
# ```

# %%
#your code/answer
for i in range(400):
    for p in particles:
        p.update_position()
        p.boxcollision()
    
    handle_collisions(particles)

print(collisions_over_time)

time = np.arange(len(collisions_over_time))

plt.figure()
plt.plot(time, collisions_over_time)
plt.xlabel("tijd")
plt.ylabel("som van het aantal botsingen")
plt.title("Aantal botsingen als functie van de tijd")
plt.show()
# Out:
# [3, 6, 6, 8, 9, 10, 12, 13, 15, 15, 15, 15, 17, 21, 23, 23, 23, 24, 25, 25, 27, 28, 28, 31, 31, 33, 33, 35, 37, 38, 39, 41, 43, 45, 46, 49, 52, 53, 54, 55, 58, 59, 62, 63, 66, 67, 68, 70, 71, 73, 74, 77, 77, 81, 82, 82, 84, 85, 86, 89, 90, 91, 92, 95, 98, 101, 102, 104, 104, 105, 105, 105, 106, 107, 107, 108, 109, 112, 113, 113, 114, 114, 116, 117, 117, 120, 121, 123, 123, 124, 124, 125, 125, 125, 125, 126, 128, 129, 131, 133, 135, 138, 140, 143, 143, 144, 145, 147, 147, 150, 150, 151, 151, 154, 155, 158, 160, 161, 164, 167, 169, 171, 171, 172, 175, 175, 177, 179, 179, 180, 181, 182, 185, 187, 188, 190, 191, 192, 194, 197, 200, 200, 200, 201, 203, 203, 203, 203, 203, 206, 207, 208, 208, 208, 209, 211, 213, 213, 215, 217, 217, 219, 219, 219, 219, 221, 223, 225, 226, 227, 231, 232, 234, 237, 238, 240, 240, 241, 242, 244, 247, 248, 250, 254, 255, 256, 257, 257, 257, 257, 263, 266, 268, 269, 271, 276, 278, 281, 282, 282, 282, 285, 287, 288, 293, 293, 294, 296, 297, 299, 301, 302, 303, 304, 305, 307, 307, 309, 311, 311, 311, 312, 314, 316, 319, 319, 319, 321, 324, 327, 329, 331, 332, 332, 333, 333, 335, 337, 339, 340, 340, 341, 342, 343, 345, 346, 347, 352, 352, 352, 353, 355, 356, 357, 357, 358, 360, 363, 366, 366, 367, 368, 369, 370, 371, 372, 375, 376, 378, 379, 381, 383, 383, 386, 387, 388, 389, 389, 390, 392, 393, 395, 395, 399, 400, 404, 405, 406, 407, 408, 411, 411, 412, 413, 415, 417, 420, 421, 423, 423, 423, 423, 424, 424, 426, 427, 429, 431, 432, 434, 438, 438, 440, 440, 442, 442, 442, 445, 445, 445, 447, 450, 453, 457, 461, 465, 465, 469, 472, 475, 476, 480, 481, 486, 488, 488, 489, 489, 494, 495, 496, 497, 498, 499, 502, 502, 502, 502, 502, 507, 508, 511, 513, 515, 516, 517, 518, 518, 520, 522, 524, 525, 525, 525, 526, 527, 528, 529, 530, 530, 532, 532, 534, 534, 535, 538, 539, 540, 544, 546, 546, 548, 550, 550, 552, 553, 554, 555, 557, 558, 559, 560, 561, 563, 564, 564, 564, 566, 567, 567, 568, 569, 571, 571, 571, 572, 573, 573, 575, 575, 576, 578, 579, 580, 581, 582, 584, 585, 587, 589, 591, 591, 592, 594, 595, 597, 599, 601, 602, 604, 607, 608, 608, 609, 610, 613, 613, 616, 618, 619, 620, 625, 626, 627, 628, 630, 631, 634, 636, 636, 637, 638, 639, 644, 644, 646, 647, 648, 650, 652, 654, 656, 657, 658, 659, 660, 661, 664, 668, 671, 672, 672, 675, 677, 678, 680, 681, 682, 682, 682, 684, 687, 688, 691, 693, 694, 695, 696, 696, 697, 700, 701, 701, 703, 705, 707, 707, 708, 709, 712, 715, 715, 716, 717, 719, 722, 724, 726, 728, 728, 728, 728, 728, 731, 731, 732, 733, 734, 734, 736, 736, 739, 740, 741, 743, 744, 745, 748, 748, 749, 749, 749, 749, 753, 753, 753, 753, 755, 757, 758, 759, 762, 763, 764, 767, 770, 773, 773, 776, 778, 778, 779, 781, 786, 788, 788, 792, 792, 793, 794, 796, 797, 800, 800, 803, 807, 807, 809, 809, 811, 811, 814, 819, 822, 824, 825, 825, 827, 828, 830, 831, 831, 831, 833, 836, 838, 840, 843, 843, 844, 847, 848, 848, 849, 851, 851, 853, 853, 855, 857, 858, 860, 860, 863, 864, 865, 869, 870, 874, 878, 880, 883, 884, 884, 885, 886, 886, 888, 889, 892, 892, 895, 896, 896, 899, 900, 901, 903, 910, 913, 917, 918, 918, 918, 918, 919, 920, 920, 921, 925, 927, 928, 930, 932, 935, 935, 935, 936, 936, 938, 939, 943, 943, 946, 948, 950, 954, 955, 956, 960, 964, 964, 967, 968, 969, 972, 975, 976, 977, 979, 982, 983, 985, 986, 987, 988, 991, 993, 994, 995, 996, 997, 1000, 1001, 1002, 1003, 1005, 1007, 1008, 1010, 1010, 1012, 1013, 1014, 1015, 1022, 1025, 1027, 1028, 1029, 1032, 1035, 1039, 1041, 1043, 1043, 1044, 1047, 1048, 1049, 1053, 1055, 1055, 1055, 1058, 1060, 1061, 1062, 1062, 1066, 1068, 1070, 1071, 1072, 1074, 1074, 1074, 1077, 1079, 1081, 1082, 1083, 1084, 1085, 1088, 1089, 1090, 1092, 1092, 1092, 1093, 1094, 1096, 1098, 1100, 1100, 1101, 1103, 1104, 1106, 1106, 1106, 1108, 1108, 1108, 1108, 1112, 1112, 1117, 1118, 1118, 1121, 1122, 1125, 1127, 1130, 1131, 1132, 1133, 1134, 1135, 1137, 1137, 1137, 1138, 1142, 1145, 1146, 1148, 1151, 1153, 1154, 1157, 1159, 1160, 1161, 1164, 1165, 1165, 1167, 1167, 1169, ...

# %% [markdown]
# ```{warning} 🌶 Let op!
# :icon: false
# De onderstaande opdrachten vallen buiten de stof maar tellen mee als je excellent wilt behalen.
# ```
#
# In zulke fysica modellen is de afgelegde weg (afstand tussen begin en eindpunt) van belang.
# Deze afgelegde weg zegt iets over de snelheid van difussie.
# Idealiter bekijken we een histogram.
# Maar voor een histogram hebben we veel deeltjes nodig.
#
#
#
# ```{exercise} Afgelegde weg 🌶
# :label: ex-brownian-4
#
# - Maak een simulatie met 361 deeltjes, waarvan 1 zwaar deeltje.
# - Houd rekening met de boxgrootte, deze moet mee schalen!
# - Maak een histogram van de afgelegde weg voor alle deeltjes.
# - Geef de afgelegde weg van het grote deeltje duidelijk aan.
# ```

# %%
#your code/answer

# %% [markdown]
# En nu we toch bezig zijn met twee verschillende deeltjes....
#
# We kunnen twee "groepen" van deeltjes aanmaken, elk  met een andere massa. Als we dan de zwaartekracht aan zetten, dan zouden we verwachten dat de lichtere deeltjes boven komen "drijven".
#
# ```{exercise} Onderzoek dit vermoeden 🌶
# - maak daartoe de box 2x zo hoog als breed
# - verdubbel het totaal aantal deeltjes
# - zet een artificieel grote zwaartekracht aan
# ```

# %%
#your code/answer
